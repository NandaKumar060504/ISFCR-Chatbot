# %%
from langchain_community.document_loaders import UnstructuredPDFLoader

# %%
a = UnstructuredPDFLoader("pdfs\\Research_Vol_2021.pdf")

# %%
data = a.load()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 data = a.load()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\langchain_core\document_loaders\base.py:29, in BaseLoader.load(self)
#      27 def load(self) -> List[Document]:
#      28     """Load data into Document objects."""
# ---> 29     return list(self.lazy_load())
#
# File ~\AppData\Roaming\Python\Python311\site-packages\langchain_community\document_loaders\unstructured.py:88, in UnstructuredBaseLoader.lazy_load(self)
#      86 def lazy_load(self) -> Iterator[Document]:
#      87     """Load file."""
# ---> 88     elements = self._get_elements()
#      89     self._post_process_elements(elements)
#      90     if self.mode == "elements":
#
# ...
